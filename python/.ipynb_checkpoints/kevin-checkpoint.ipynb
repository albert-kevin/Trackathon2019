# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/jovyan/python

# %%
# !head ../data/dataset/Raw_punctuality_201904.csv
# Out:
# DATDEP,TRAIN_NO,RELATION,TRAIN_SERV,PTCAR_NO,LINE_NO_DEP,REAL_TIME_ARR,REAL_TIME_DEP,PLANNED_TIME_ARR,PLANNED_TIME_DEP,DELAY_ARR,DELAY_DEP,RELATION_DIRECTION,PTCAR_LG_NM_NL,LINE_NO_ARR,PLANNED_DATE_ARR,PLANNED_DATE_DEP,REAL_DATE_ARR,REAL_DATE_DEP
# 01APR2019,116,IC 33,SNCB/NMBS,734,34L/1,,15:28:09,,15:30:00,,-111,IC 33: LIERS -> LUXEMBOURG,LIERS-FAISCEAU,,,01APR2019,,01APR2019
# 01APR2019,116,IC 33,SNCB/NMBS,733,34,15:32:09,15:35:02,15:34:00,15:35:00,-111,2,IC 33: LIERS -> LUXEMBOURG,LIERS,34L/1,01APR2019,01APR2019,01APR2019,01APR2019
# 01APR2019,116,IC 33,SNCB/NMBS,835,34,15:38:02,15:38:39,15:38:00,15:39:00,2,-21,IC 33: LIERS -> LUXEMBOURG,MILMORT,34,01APR2019,01APR2019,01APR2019,01APR2019
# 01APR2019,116,IC 33,SNCB/NMBS,562,34,15:43:39,15:54:30,15:44:00,15:45:00,-21,570,IC 33: LIERS -> LUXEMBOURG,HERSTAL,34,01APR2019,01APR2019,01APR2019,01APR2019
# ...

# %%
df = pd.read_csv("../data/dataset/Raw_punctuality_201904.csv")

# %%
df["DATDEP"] = pd.to_datetime(df["DATDEP"], format='%d%b%Y')

# %%
df.sample(10).T
# Out:
#                                                       411230   \
# DATDEP                                    2019-04-07 00:00:00
# TRAIN_NO                                                 3307
# RELATION                                                IC 22
# TRAIN_SERV                                          SNCB/NMBS
# PTCAR_NO                                                  220
# LINE_NO_DEP                                               0/5
# REAL_TIME_ARR                                             NaN
# REAL_TIME_DEP                                         7:28:45
# PLANNED_TIME_ARR                                          NaN
# PLANNED_TIME_DEP                                      7:28:00
# DELAY_ARR                                                 NaN
# DELAY_DEP                                                  45
# RELATION_DIRECTION  IC 22: BRUSSEL-ZUID -> ANTWERPEN-CENTRAAL
# PTCAR_LG_NM_NL                                   BRUSSEL-ZUID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449856 entries, 0 to 1449855
# Data columns (total 19 columns):
# DATDEP                1449856 non-null datetime64[ns]
# TRAIN_NO              1449856 non-null int64
# RELATION              1449856 non-null object
# TRAIN_SERV            1449856 non-null object
# PTCAR_NO              1449856 non-null int64
# LINE_NO_DEP           1376443 non-null object
# REAL_TIME_ARR         1378176 non-null object
# REAL_TIME_DEP         1378269 non-null object
# PLANNED_TIME_ARR      1378176 non-null object
# PLANNED_TIME_DEP      1378268 non-null object
# DELAY_ARR             1378325 non-null float64
# DELAY_DEP             1378270 non-null float64
# RELATION_DIRECTION    1362070 non-null object
# PTCAR_LG_NM_NL        1449856 non-null object
# LINE_NO_ARR           1376350 non-null object
# PLANNED_DATE_ARR      1378176 non-null object
# PLANNED_DATE_DEP      1378268 non-null object
# REAL_DATE_ARR         1378176 non-null object
# ...

# %%
df[df["TRAIN_NO"]==537].sample(5).T
# Out:
#                                      1286057                   1443185  \
# DATDEP                   2019-04-22 00:00:00       2019-04-24 00:00:00
# TRAIN_NO                                 537                       537
# RELATION                               IC 01                     IC 01
# TRAIN_SERV                         SNCB/NMBS                 SNCB/NMBS
# PTCAR_NO                                1180                      1048
# LINE_NO_DEP                               37                       36N
# REAL_TIME_ARR                       14:41:16                  15:48:40
# REAL_TIME_DEP                       14:41:16                  15:48:40
# PLANNED_TIME_ARR                    14:27:00                  15:47:00
# PLANNED_TIME_DEP                    14:27:00                  15:47:00
# DELAY_ARR                                856                       100
# DELAY_DEP                                856                       100
# ...

# %%
df[(df["TRAIN_NO"]==537) & (df["PTCAR_LG_NM_NL"]=="VERVIERS-CENTRAL")].T
# Out:
#                                      63232                     126505   \
# DATDEP                   2019-04-01 00:00:00       2019-04-02 00:00:00
# TRAIN_NO                                 537                       537
# RELATION                               IC 01                     IC 01
# TRAIN_SERV                         SNCB/NMBS                 SNCB/NMBS
# PTCAR_NO                                1177                      1177
# LINE_NO_DEP                               37                        37
# REAL_TIME_ARR                       14:38:23                  14:39:19
# REAL_TIME_DEP                       14:39:23                  14:40:19
# PLANNED_TIME_ARR                    14:38:02                  14:38:02
# PLANNED_TIME_DEP                    14:39:02                  14:39:02
# DELAY_ARR                                 23                        79
# DELAY_DEP                                 23                        79
# ...

# %%
df[(df["TRAIN_NO"]==537) & (df["PTCAR_LG_NM_NL"]=="VERVIERS-CENTRAL")]["DATDEP"].sort_values()
# Out:
# 63232     2019-04-01
# 126505    2019-04-02
# 201981    2019-04-03
# 263369    2019-04-04
# 313104    2019-04-05
# 399671    2019-04-06
# 416082    2019-04-07
# 455716    2019-04-08
# 531594    2019-04-09
# 605218    2019-04-10
# 705624    2019-04-11
# 772605    2019-04-12
# 798054    2019-04-13
# 845942    2019-04-14
# 920600    2019-04-15
# 955023    2019-04-16
# 1058020   2019-04-17
# 1104412   2019-04-18
# 1185675   2019-04-19
# 1219040   2019-04-20
# 1268069   2019-04-21
# 1286058   2019-04-22
# 1340042   2019-04-23
# 1443165   2019-04-24
# Name: DATDEP, dtype: datetime64[ns]

# %%
df[(df["TRAIN_NO"]==537) & (df["PTCAR_LG_NM_NL"]=="VERVIERS-CENTRAL")]["DATDEP"]
# Out:
# 63232     2019-04-01
# 126505    2019-04-02
# 201981    2019-04-03
# 263369    2019-04-04
# 313104    2019-04-05
# 399671    2019-04-06
# 416082    2019-04-07
# 455716    2019-04-08
# 531594    2019-04-09
# 605218    2019-04-10
# 705624    2019-04-11
# 772605    2019-04-12
# 798054    2019-04-13
# 845942    2019-04-14
# 920600    2019-04-15
# 955023    2019-04-16
# 1058020   2019-04-17
# 1104412   2019-04-18
# 1185675   2019-04-19
# 1219040   2019-04-20
# 1268069   2019-04-21
# 1286058   2019-04-22
# 1340042   2019-04-23
# 1443165   2019-04-24
# Name: DATDEP, dtype: datetime64[ns]

# %%
df_537 = df[(df["TRAIN_NO"]==537) & (df["PTCAR_LG_NM_NL"]=="VERVIERS-CENTRAL")]

# %%
df_537
# Out:
#             DATDEP  TRAIN_NO RELATION TRAIN_SERV  PTCAR_NO LINE_NO_DEP  \
# 63232   2019-04-01       537    IC 01  SNCB/NMBS      1177          37
# 126505  2019-04-02       537    IC 01  SNCB/NMBS      1177          37
# 201981  2019-04-03       537    IC 01  SNCB/NMBS      1177          37
# 263369  2019-04-04       537    IC 01  SNCB/NMBS      1177          37
# 313104  2019-04-05       537    IC 01  SNCB/NMBS      1177          37
# 399671  2019-04-06       537    IC 01  SNCB/NMBS      1177          37
# 416082  2019-04-07       537    IC 01  SNCB/NMBS      1177          37
# 455716  2019-04-08       537    IC 01  SNCB/NMBS      1177          37
# 531594  2019-04-09       537    IC 01  SNCB/NMBS      1177          37
# 605218  2019-04-10       537    IC 01  SNCB/NMBS      1177          37
# 705624  2019-04-11       537    IC 01  SNCB/NMBS      1177          37
# 772605  2019-04-12       537    IC 01  SNCB/NMBS      1177          37
# ...

# %%
df_537.head(5)
# Out:
#            DATDEP  TRAIN_NO RELATION TRAIN_SERV  PTCAR_NO LINE_NO_DEP  \
# 63232  2019-04-01       537    IC 01  SNCB/NMBS      1177          37
# 126505 2019-04-02       537    IC 01  SNCB/NMBS      1177          37
# 201981 2019-04-03       537    IC 01  SNCB/NMBS      1177          37
# 263369 2019-04-04       537    IC 01  SNCB/NMBS      1177          37
# 313104 2019-04-05       537    IC 01  SNCB/NMBS      1177          37
#
#        REAL_TIME_ARR REAL_TIME_DEP PLANNED_TIME_ARR PLANNED_TIME_DEP  \
# 63232       14:38:23      14:39:23         14:38:02         14:39:02
# 126505      14:39:19      14:40:19         14:38:02         14:39:02
# 201981      14:44:57      14:45:57         14:38:02         14:39:02
# 263369      14:40:47      14:41:47         14:38:02         14:39:02
# 313104      14:38:03      14:39:03         14:38:02         14:39:02
#
#         DELAY_ARR  DELAY_DEP        RELATION_DIRECTION    PTCAR_LG_NM_NL  \
# ...

# %%
df_537.head(5)
# Out:
#            DATDEP  TRAIN_NO RELATION TRAIN_SERV  PTCAR_NO LINE_NO_DEP  \
# 63232  2019-04-01       537    IC 01  SNCB/NMBS      1177          37
# 126505 2019-04-02       537    IC 01  SNCB/NMBS      1177          37
# 201981 2019-04-03       537    IC 01  SNCB/NMBS      1177          37
# 263369 2019-04-04       537    IC 01  SNCB/NMBS      1177          37
# 313104 2019-04-05       537    IC 01  SNCB/NMBS      1177          37
#
#        REAL_TIME_ARR REAL_TIME_DEP PLANNED_TIME_ARR PLANNED_TIME_DEP  \
# 63232       14:38:23      14:39:23         14:38:02         14:39:02
# 126505      14:39:19      14:40:19         14:38:02         14:39:02
# 201981      14:44:57      14:45:57         14:38:02         14:39:02
# 263369      14:40:47      14:41:47         14:38:02         14:39:02
# 313104      14:38:03      14:39:03         14:38:02         14:39:02
#
#         DELAY_ARR  DELAY_DEP        RELATION_DIRECTION    PTCAR_LG_NM_NL  \
# ...

# %%
df["DATDEP"] = pd.to_datetime(df["DATDEP"], format='%d%b%Y')

# %%
# !pwd
# Out:
# /home/jovyan/python

# %% [markdown]
# ## from Verviers

# %%
df_537[["DATDEP", "DELAY_DEP"]].reset_index().to_csv("Verviers_537_depart.csv")

# %%
df_537_b = df[(df["TRAIN_NO"]==537) & (df["PTCAR_LG_NM_NL"]=="LIEGE-GUILLEMINS")]

# %%
df_537_b[["DATDEP", "DELAY_ARR"]].reset_index(inplace=True, drop=True)

# %% [markdown]
# ## to Liege

# %%
df_537_b[["DATDEP", "DELAY_ARR"]].reset_index().to_csv("Liege_537_arrival.csv")

# %%
df_3837 = df[(df["TRAIN_NO"]==3837) & (df["PTCAR_LG_NM_NL"]=="LIEGE-GUILLEMINS")]

# %%
import seaborn as sns

# %%
df_537_b["DELAY_ARR"].reset_index()["DELAY_ARR"].plot(kind='hist')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(14,10))
sns.distplot(df_537_b["DELAY_ARR"].reset_index()["DELAY_ARR"])
plt.savefig("delay.png")
